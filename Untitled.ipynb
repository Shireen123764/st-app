# %%
import plotly.express as px
import pandas as pd

# %%
df=pd.read_csv("cric_info.csv")

# %%
df
# Out:
#           Player  Duration  Matches  innings  NO  Runs  High_score    Ave  \
# 0    DG Bradman         20       52       80  10  6996         334  99.94
# 1   PHKD Mendis          3       12       21   2  1184         182  62.31
# 2      AC Voges          1       20       31   7  1485         269  61.87
# 3    RG Pollock          7       23       41   4  2256         274  60.97
# 4    GA Headley         24       22       40   4  2190         270  60.83
# ..           ...       ...      ...      ...  ..   ...         ...    ...
# 57   KD Walters         16       74      125  14  5357         250  48.26
# 58     GC Smith         12      117      205  13  9265         277  48.25
# 59  WH Ponsford         10       29       48   4  2122         266  48.22
# 60    SJ McCabe          8       39       62   5  2748         232  48.21
# 61   DR Jardine          6       22       33   6  1296         127  48.00
#
#     Balls_faced  Strike_rate  100  50   0    4s  6s Country  start_year  \
# ...

# %%
pdata=df[df["Player"]== 'DG Bradman ']

# %%
pdata
# Out:
#         Player  Duration  Matches  innings  NO  Runs  High_score    Ave  \
# 0  DG Bradman         20       52       80  10  6996         334  99.94
#
#    Balls_faced  Strike_rate  100  50  0   4s  6s Country  start_year  end_year
# 0         9800         58.6   29  13  7  626   6     AUS        1928      1948

# %%
pdata["Player"]
# Out:
# 0    DG Bradman
# Name: Player, dtype: str

# %%
df2=pdata[["Runs","Matches","innings","6s","4s","100","50","Ave","High_score"]]

# %%
df2=df2.T.reset_index()# transpose

# %%
df2.rename(columns={0:"Values"," ":"new"})
# Out:
#         index   Values
# 0        Runs  6996.00
# 1     Matches    52.00
# 2     innings    80.00
# 3          6s     6.00
# 4          4s   626.00
# 5         100    29.00
# 6          50    13.00
# 7         Ave    99.94
# 8  High_score   334.00

# %%
df2.columns.name = "Names"
df2
# Out:
# Names       index        0
# 0            Runs  6996.00
# 1         Matches    52.00
# 2         innings    80.00
# 3              6s     6.00
# 4              4s   626.00
# 5             100    29.00
# 6              50    13.00
# 7             Ave    99.94
# 8      High_score   334.00

# %%
px.bar(df2 , x="Names", y="Values")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 px.bar(df2 , x="Names", y="Values")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\plotly\express\_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
# ...
